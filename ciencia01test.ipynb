# %%
num1=5
num2=9
suma=num1+num2
suma
# Out:
# 14

# %% [markdown]
# Importamos la libreria de pandas

# %%
import pandas as pd

# %% [markdown]
# creamos el DataFrame

# %%
datos={
    "Nombres": ["Ana", "Adrian", "Lucia", "Antonia"],
    "Edad": [23, 34, 32, 20],
    "Ciudades":["Madrid", "Barcelona", "Salamanca", "Valencia"]
}

# %% [markdown]
# creamos un DataFrame con los datos

# %%
df=pd.DataFrame(datos)
df
# Out:
#    Nombres  Edad   Ciudades
# 0      Ana    23     Madrid
# 1   Adrian    34  Barcelona
# 2    Lucia    32  Salamanca
# 3  Antonia    20   Valencia

# %% [markdown]
# Voy a filtrar datos por edad

# %%
df[df['Edad']>24]
# Out:
#   Nombres  Edad   Ciudades
# 1  Adrian    34  Barcelona
# 2   Lucia    32  Salamanca
